# %% [markdown]
# # Sales Performance Analysis
#
# ---
#
#
#
# ---

# %% [markdown]
# # Objective (Part 2)
#
#
#
# Analyze sales data to identify trends, relationships, and factors affecting sales performance

# %% [markdown]
# # Import Libraries
#
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load the dataset
#
# ---

# %%
df = pd.read_csv('/content/superstore.csv')

# %% [markdown]
# # Display the few rows
#
# ---

# %%
print("First 5 rows of the dataset:")
display(df.head())
# Out:
# First 5 rows of the dataset:
#           Category         City        Country Customer.ID     Customer.Name  \
# 0  Office Supplies  Los Angeles  United States   LS-172304  Lycoris Saunders
# 1  Office Supplies  Los Angeles  United States   MV-174854     Mark Van Huff
# 2  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 3  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 4  Office Supplies  Los Angeles  United States   AP-109154    Arthur Prichep
#
#    Discount Market  记录数               Order.Date        Order.ID  ... Sales  \
# 0       0.0     US    1  2011-01-07 00:00:00.000  CA-2011-130813  ...    19
# 1       0.0     US    1  2011-01-21 00:00:00.000  CA-2011-148614  ...    19
# 2       0.0     US    1  2011-08-05 00:00:00.000  CA-2011-118962  ...    21
# 3       0.0     US    1  2011-08-05 00:00:00.000  CA-2011-118962  ...   111
# 4       0.0     US    1  2011-09-29 00:00:00.000  CA-2011-146969  ...     6
#
# ...

# %%
df.tail()
# Out:
#               Category         City        Country Customer.ID  \
# 51285  Office Supplies  Los Angeles  United States   AM-103604
# 51286  Office Supplies  Los Angeles  United States   AM-103604
# 51287  Office Supplies  Los Angeles  United States   HR-147704
# 51288  Office Supplies  Los Angeles  United States   RM-196754
# 51289  Office Supplies  Los Angeles  United States   FH-143654
#
#         Customer.Name  Discount Market  记录数               Order.Date  \
# 51285  Alice McCarthy       0.2     US    1  2014-12-03 00:00:00.000
# 51286  Alice McCarthy       0.2     US    1  2014-12-03 00:00:00.000
# 51287  Hallie Redmond       0.2     US    1  2014-12-18 00:00:00.000
# 51288   Robert Marley       0.2     US    1  2014-12-25 00:00:00.000
# 51289    Fred Hopkins       0.2     US    1  2014-12-26 00:00:00.000
#
#              Order.ID  ... Sales      Segment                Ship.Date  \
# 51285  CA-2014-109701  ...    69    Corporate  2014-12-04 00:00:00.000
# ...

# %% [markdown]
# # Basic information about the dataset
#
# ---

# %%
print("\nDataset Information:")
df.info()
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 27 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Category        51290 non-null  object
#  1   City            51290 non-null  object
#  2   Country         51290 non-null  object
#  3   Customer.ID     51290 non-null  object
#  4   Customer.Name   51290 non-null  object
#  5   Discount        51290 non-null  float64
#  6   Market          51290 non-null  object
#  7   记录数             51290 non-null  int64
#  8   Order.Date      51290 non-null  object
#  9   Order.ID        51290 non-null  object
#  10  Order.Priority  51290 non-null  object
#  11  Product.ID      51290 non-null  object
#  12  Product.Name    51290 non-null  object
#  13  Profit          51290 non-null  float64
#  14  Quantity        51290 non-null  int64
#  15  Region          51290 non-null  object
# ...

# %%
df.describe()
# Out:
#            Discount      记录数        Profit      Quantity       Row.ID  \
# count  51290.000000  51290.0  51290.000000  51290.000000  51290.00000
# mean       0.142908      1.0     28.610982      3.476545  25645.50000
# std        0.212280      0.0    174.340972      2.278766  14806.29199
# min        0.000000      1.0  -6599.978000      1.000000      1.00000
# 25%        0.000000      1.0      0.000000      2.000000  12823.25000
# 50%        0.000000      1.0      9.240000      3.000000  25645.50000
# 75%        0.200000      1.0     36.810000      5.000000  38467.75000
# max        0.850000      1.0   8399.976000     14.000000  51290.00000
#
#               Sales  Shipping.Cost          Year       weeknum
# count  51290.000000   51290.000000  51290.000000  51290.000000
# mean     246.498440      26.375818   2012.777208     31.287112
# std      487.567175      57.296810      1.098931     14.429795
# min        0.000000       0.002000   2011.000000      1.000000
# ...

# %%
df.rename(columns={"记录数":"Number of Records"}, inplace=True) #rename column name

df["Number of Records"].head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Number of Records, dtype: int64

# %% [markdown]
# # Statistical summary of numerical columns
#
# ---

# %%
print("\nStatistical Summary:")
display(df.describe())
# Out:
# Statistical Summary:
#            Discount  Number of Records        Profit      Quantity  \
# count  51290.000000            51290.0  51290.000000  51290.000000
# mean       0.142908                1.0     28.610982      3.476545
# std        0.212280                0.0    174.340972      2.278766
# min        0.000000                1.0  -6599.978000      1.000000
# 25%        0.000000                1.0      0.000000      2.000000
# 50%        0.000000                1.0      9.240000      3.000000
# 75%        0.200000                1.0     36.810000      5.000000
# max        0.850000                1.0   8399.976000     14.000000
#
#             Row.ID         Sales  Shipping.Cost          Year       weeknum
# count  51290.00000  51290.000000   51290.000000  51290.000000  51290.000000
# mean   25645.50000    246.498440      26.375818   2012.777208     31.287112
# std    14806.29199    487.567175      57.296810      1.098931     14.429795
# ...

# %% [markdown]
# # Check for duplicates
#
# ---

# %%
duplicates = df.duplicated().sum()
print(f"\nNumber of duplicate rows: {duplicates}")
# Out:
# Number of duplicate rows: 0

# %% [markdown]
# # Handle missing values
#
# ---

# %%
print(f"Missing values before cleaning:\n{df.isnull().sum()}")
# Out:
# Missing values before cleaning:
# Category             0
# City                 0
# Country              0
# Customer.ID          0
# Customer.Name        0
# Discount             0
# Market               0
# Number of Records    0
# Order.Date           0
# Order.ID             0
# Order.Priority       0
# Product.ID           0
# Product.Name         0
# Profit               0
# Quantity             0
# Region               0
# Row.ID               0
# Sales                0
# Segment              0
# Ship.Date            0
# Ship.Mode            0
# Shipping.Cost        0
# State                0
# Sub.Category         0
# Year                 0
# Market2              0
# weeknum              0
# dtype: int64

# %% [markdown]
# # Convert 'Date' column to datetime format and verify
#
# ---

# %%
df['Order.Date'] = pd.to_datetime(df['Order.Date'])
df['Ship.Date'] = pd.to_datetime(df['Ship.Date'])

# %% [markdown]
# #  Create a new column for processing time
#
# ---

# %%
df['Processing.Time'] = (df['Ship.Date'] - df['Order.Date']).dt.days

# %% [markdown]
# # Exploratory Data Analysis
#
# ---

# %% [markdown]
# # Plot time series graphs to observe trends in Sales over time.
#
# ---

# %%
plt.figure(figsize=(10,6))
df.groupby('Order.Date')['Sales'].sum().plot(kind='line', color='blue')
plt.title('Sales Trend Over Time')
plt.xlabel('Date')
plt.ylabel('Total Sales')
plt.show()

# %% [markdown]
# # Use scatter plots to study the relationship between Profit and Discount

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='Discount', y='Profit', data=df, color='orange')
plt.title('Profit vs Discount')
plt.xlabel('Discount')
plt.ylabel('Profit')
plt.show()

# %% [markdown]
# # Sales distribution by Region
#
# ---

# %%
plt.figure(figsize=(8,6))
region_sales =  df.groupby('Region')['Sales'].sum()
region_sales.plot(kind='bar', color='green')
plt.title('Sales Distribution by Region')
plt.xlabel('Region')
plt.ylabel('Total sales')
plt.show()

# %% [markdown]
# # Sales distribution by Category
#
# ---

# %%
plt.figure(figsize=(8,6))
sales_distribution_by_category = df.groupby('Category')['Sales'].sum()
sales_distribution_by_category.plot(kind='bar',color='pink',alpha=0.7)
plt.title('sales distribution by category')
plt.xlabel('Category')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# # Sales distribution by Sub-category
#
# ---

# %%
sales_distribution_by_category = df.groupby('Sub.Category')['Sales'].sum()
sales_distribution_by_category.plot(kind='bar',figsize=[10,6],color='black')
plt.title('Sales distribution by sub-category ')
plt.xlabel('Sub-Category')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# # Sales Heatmap by Category and Region
#
# ---

# %%
pivot_table = df.pivot_table(values='Sales', index='Region', columns='Category', aggfunc='sum')
plt.figure(figsize=(10, 6))
sns.heatmap(pivot_table, annot=True, fmt=".0f", cmap="coolwarm", linewidths=0.5)
plt.title("Sales Heatmap by Category and Region", fontsize=14, weight='bold')
plt.xlabel("Category", fontsize=12)
plt.ylabel("Region", fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Heatmaps to visualize correlations and relationships between features
#
# ---

# %%
# Select only numerical features for correlation analysis
numerical_df = df.select_dtypes(include=['number'])

plt.figure(figsize=(10, 6))
sns.heatmap(numerical_df.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 35760 (\N{CJK UNIFIED IDEOGRAPH-8BB0}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 24405 (\N{CJK UNIFIED IDEOGRAPH-5F55}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 35760 (\N{CJK UNIFIED IDEOGRAPH-8BB0}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 24405 (\N{CJK UNIFIED IDEOGRAPH-5F55}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# # Sales distribution by region
#
# ---

# %%
sales_distribution = df.groupby('Region')['Sales'].sum()
sales_distribution.plot(kind='pie',color='brown',legend=True)
plt.title('Sales Distribution by Region')
plt.ylabel('') # This removes the y-label
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# # Select Features and Target
#
# ---

# %%
X = df[['Profit', 'Discount']]
Y = df['Sales']

# %% [markdown]
# # Split the dataset into trainting and test sets
#
# ---

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, random_state=42)

# %% [markdown]
# # Train the Linear Regression model
#
# ---

# %%
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Make Predictions

# %%
Y_pred = model.predict(X_test)
print(Y_pred)
# Out:
# [220.25546787 250.68303541 189.67504762 ... 217.55582443 272.437046
#  245.59934886]

# %% [markdown]
# # Evaluate the model
#
# ---

# %%
print(f"Mean Squared Error: {mean_squared_error(Y_test, Y_pred):.2f}")
print(f"R-squared: {r2_score(Y_test, Y_pred):.2f}")
# Out:
# Mean Squared Error: 241642.62
# R-squared: 0.11

# %% [markdown]
# #  Here are some insights and recommendations:
#
# # 1. Optimal Discount Rates:
#    - Analyze the impact of discount rates on sales by region and category. Identify if certain regions or categories respond better to discounts.
#    - Conduct A/B testing with different discount rates to determine the optimal discount strategy for maximizing sales without significantly impacting profit margins.
#
# # 2. Top-Performing Regions:
#    - Identify the top-performing regions in terms of sales. Focus on allocating more resources, marketing efforts, and promotions in these regions to further boost sales.
#    - Explore the reasons behind the success of these regions, such as customer preferences, market demand, or effective marketing strategies.
#
# # 3. Top-Performing Categories:
#    - Determine the top-performing product categories based on sales data. Allocate resources and marketing efforts towards promoting these categories to drive overall sales growth.
#    - Identify any underperforming categories and develop strategies to improve their sales performance, such as targeted promotions or product enhancements.
#
# # 4. Relationships Between Features:
#    - Use the heatmap visualization to identify correlations between different categories and regions with sales performance.
#    - Explore any strong positive or negative correlations to understand which factors influence sales the most. For example, if a specific category performs well in a particular region, consider expanding marketing efforts in similar regions or diversifying product offerings.
#
# # 5. Market Segmentation:
#    - Segment customers based on their purchasing behavior, preferences, and demographics to tailor marketing strategies and promotions accordingly.
#    - Target specific customer segments with personalized offers, discounts, or product recommendations to increase customer engagement and drive sales.
#
# # 6. Forecasting and Inventory Management:
#    - Use historical sales data to forecast future sales trends and demand patterns. Adjust inventory levels and product availability to meet customer demand and avoid stockouts.
#    - Implement inventory management strategies such as just-in-time inventory or demand forecasting to optimize stock levels and minimize excess inventory costs.
#
#
#
# However, the R-squared value (0.11) in the linear regression model indicates
#   a poor fit, suggesting that the relationship between the selected features (Profit and Discount) and the target (Sales) is weak. This could imply that the model is not capturing the key drivers of sales performance. Enhancing feature selection or using more complex models might improve predictive power.
#
# By implementing these insights and recommendations, businesses can optimize their sales strategies, improve overall performance, and drive sustainable growth in sales revenue.
#
# ---
